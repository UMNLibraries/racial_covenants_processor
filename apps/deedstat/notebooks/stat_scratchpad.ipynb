# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'racial_covenants_processor.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from django.db.models import Count

import pandas as pd
import altair as alt

from apps.deed.models import DeedPage, MatchTerm
from apps.zoon.models import ZooniverseWorkflow, ZooniverseSubject, ManualCovenant
from apps.parcel.utils.export_utils import build_gdf

from django.conf import settings

# %% [markdown]
# # 1. Overall confirmation rate

# %%
def calculate_confirm_rate(workflow_name, exclude_terms=None):
    workflow = ZooniverseWorkflow.objects.get(workflow_name=workflow_name)
    
    if exclude_terms:
        exclude_kwargs = {
            'matched_terms__term__in': exclude_terms
        }
    else:
        exclude_kwargs = {}
    
    df = pd.DataFrame(
        DeedPage.objects.filter(
            workflow=workflow,
            bool_match=True
        ).exclude(
            zooniverse_subject__isnull=True
        ).exclude(
            zooniverse_subject__bool_handwritten=True
        ).exclude(
            **exclude_kwargs
        ).values(
            'zooniverse_subject__bool_covenant_final'
        ).annotate(
            bool_covenant=Count('zooniverse_subject__bool_covenant_final')
        )
    )
    df['pct_of_total'] = df['bool_covenant'] / df['bool_covenant'].sum()
    return df

# %%
calculate_confirm_rate('Ramsey County')
# Out:
#   zooniverse_subject__bool_covenant_final  bool_covenant  pct_of_total
# 0                                   False          46285      0.950177
# 1                                    True           2427      0.049823
# 2                                    None              0      0.000000

# %%
workflows = ZooniverseWorkflow.objects.all()
for w in workflows:
    print(w.workflow_name)
# Out:
# Ramsey County
# MA South Essex County
# WI Milwaukee County
# MN Dakota County
# MN Anoka County
# MN Ramsey County
# MN Sherburne County
# MN Olmsted County
# MN Washington County

# %%
calculate_confirm_rate('MN Dakota County')
# Out:
#   zooniverse_subject__bool_covenant_final  bool_covenant  pct_of_total
# 0                                   False            221      0.107126
# 1                                    True           1842      0.892874
# 2                                    None              0      0.000000

# %%
calculate_confirm_rate('WI Milwaukee County')
# Out:
#   zooniverse_subject__bool_covenant_final  bool_covenant  pct_of_total
# 0                                   False           5546      0.492016
# 1                                    True           5726      0.507984
# 2                                    None              0      0.000000

# %%
calculate_confirm_rate('MN Anoka County')
# Out:
#   zooniverse_subject__bool_covenant_final  bool_covenant  pct_of_total
# 0                                   False            713       0.55834
# 1                                    True            564       0.44166
# 2                                    None              0       0.00000

# %%
# Milwaukee confirmation rate without "citizen"
calculate_confirm_rate('WI Milwaukee County', ['citizen'])
# Out:
#   zooniverse_subject__bool_covenant_final  bool_covenant  pct_of_total
# 0                                   False           2132      0.272008
# 1                                    True           5706      0.727992
# 2                                    None              0      0.000000

# %%
# Anoka confirmation rate without "citizen"
calculate_confirm_rate('WI Milwaukee County', ['citizen'])
# Out:
#   zooniverse_subject__bool_covenant_final  bool_covenant  pct_of_total
# 0                                   False           2132      0.272008
# 1                                    True           5706      0.727992
# 2                                    None              0      0.000000

# %% [markdown]
# # 2. Frequency of terms appearing in workflow

# %%
def calculate_term_stats_by_doc(workflow_name):
    workflow = ZooniverseWorkflow.objects.get(workflow_name=workflow_name)
    
    # All DeedPage objects
    term_dp_df = pd.DataFrame(DeedPage.objects.filter(workflow=workflow).values('matched_terms__term').annotate(term_count=Count('matched_terms__term')).order_by('-term_count'))
    # term_dp_df

    # Retired subjects
    term_ret_df = pd.DataFrame(DeedPage.objects.filter(workflow=workflow, zooniverse_subject__isnull=False, zooniverse_subject__bool_handwritten=False).values('matched_terms__term').annotate(term_count=Count('matched_terms__term')).order_by('-term_count'))
    # term_ret_df
    
    # Confirmed covenants
    term_cov_df = pd.DataFrame(DeedPage.objects.filter(workflow=workflow, zooniverse_subject__bool_covenant_final=True, zooniverse_subject__bool_handwritten=False).values('matched_terms__term').annotate(term_count=Count('matched_terms__term')).order_by('-term_count'))
    # term_cov_df
    
    workflow_term_df = term_dp_df.rename(columns={'term_count': 'DeedPages'}).merge(
        term_ret_df.rename(columns={'term_count': 'Retired subjects'}),
        how="left",
        on="matched_terms__term"
    ).merge(
        term_cov_df.rename(columns={'term_count': 'Confirmed covenants'}),
        how="left",
        on="matched_terms__term"
    )
    
    cov_docs_count_zoon = ZooniverseSubject.objects.filter(workflow=workflow, bool_covenant_final=True).count()
    cov_docs_count_man = ManualCovenant.objects.filter(workflow=workflow).count()
    
    workflow_term_df.fillna(0, inplace=True)
    workflow_term_df['Confirm rate'] = workflow_term_df['Confirmed covenants'] / workflow_term_df['Retired subjects']
    
    workflow_term_df['Pct of covenants'] = workflow_term_df['Confirmed covenants'] / (cov_docs_count_zoon + cov_docs_count_man)
    
    workflow_term_df = workflow_term_df.sort_values(['Retired subjects'], ascending=False)
    workflow_term_df
    
    return workflow_term_df

# %%
dakota_term_stats_by_doc = calculate_term_stats_by_doc('MN Dakota County')
dakota_term_stats_by_doc
# Out:
#    matched_terms__term  DeedPages  Retired subjects  Confirmed covenants  \
# 1                negro        820             691.0                682.0
# 2          nationality        575             569.0                558.0
# 3             japanese        523             477.0                474.0
# 4              chinese        505             462.0                457.0
# 5            caucasian        466             451.0                444.0
# 6            mongolian        416             405.0                403.0
# 7    domestic servants        360             357.0                352.0
# 8              colored        352             300.0                216.0
# 9              african        276             253.0                244.0
# 11             turkish        236             234.0                231.0
# 12             moorish        218             216.0                214.0
# 13          white race         49              49.0                 48.0
# 14               irish         44              34.0                  1.0
# 15              polish         26              21.0                  1.0
# 16              jewish         19              19.0                  2.0
# 10     occupied by any        274              17.0                 17.0
# 18             italian         15              10.0                  0.0
# 19             mexican          6               5.0                  0.0
# 20                jew           6               4.0                  0.0
# 22             persian          4               3.0                  2.0
# 23              hebrew          3               3.0                  0.0
# 0              citizen       1502               3.0                  2.0
# 21              mulato          4               2.0                  0.0
# 17              racial         16               2.0                  0.0
# 24               aryan          3               1.0                  0.0
# 25               malay          3               1.0                  0.0
# 26              syrian          1               1.0                  0.0
# 27      persons not of          1               1.0                  1.0
# 28                   0          0               0.0                  0.0
#
#     Confirm rate  Pct of covenants
# 1       0.986975          0.340489
# 2       0.980668          0.278582
# 3       0.993711          0.236645
# 4       0.989177          0.228158
# 5       0.984479          0.221667
# 6       0.995062          0.201198
# 7       0.985994          0.175736
# 8       0.720000          0.107838
# 9       0.964427          0.121817
# 11      0.987179          0.115327
# 12      0.990741          0.106840
# 13      0.979592          0.023964
# 14      0.029412          0.000499
# 15      0.047619          0.000499
# 16      0.105263          0.000999
# 10      1.000000          0.008487
# 18      0.000000          0.000000
# 19      0.000000          0.000000
# 20      0.000000          0.000000
# 22      0.666667          0.000999
# 23      0.000000          0.000000
# 0       0.666667          0.000999
# 21      0.000000          0.000000
# 17      0.000000          0.000000
# 24      0.000000          0.000000
# 25      0.000000          0.000000
# 26      0.000000          0.000000
# 27      1.000000          0.000499
# 28           NaN          0.000000

# %%
def calculate_term_stats_by_lot(workflow_name, terms_list_manual=False, cov_df_manual=False):
    
    
    if isinstance(cov_df_manual, pd.DataFrame):
        workflow = None
        covenanted_lots_df = cov_df_manual[['db_id', 'cov_text']].copy()
    else:
        workflow = ZooniverseWorkflow.objects.get(workflow_name=workflow_name)
        covenanted_lots_df = build_gdf(workflow)[['db_id', 'cov_text']]
    
    if terms_list_manual:
        match_terms = terms_list_manual
    else:
        match_terms = [term for term in DeedPage.objects.filter(workflow=workflow).values_list('matched_terms__term', flat=True).distinct() if term is not None]

    for term in match_terms:
        covenanted_lots_df[term] = covenanted_lots_df['cov_text'].str.contains(term, case=False)
            
    covenanted_lots_df['num_terms'] = covenanted_lots_df[match_terms].eq(True).sum(axis=1)
    
    out_df = pd.DataFrame(columns=['term', 'term_lot_count', 'all_term_lot_count', 'solo_lot_count', 'median_num_terms'])
    for key, term in enumerate(match_terms):
        
        term_lot_count = covenanted_lots_df[covenanted_lots_df[term] == True].shape[0]
        solo_lot_count = covenanted_lots_df[(covenanted_lots_df[term] == True) & (covenanted_lots_df['num_terms'] == 1)].shape[0]
        median_num_terms = covenanted_lots_df[covenanted_lots_df[term] == True]['num_terms'].median() 
        
        new_row = pd.DataFrame({'term': term,
                                'term_lot_count': term_lot_count,
                                'solo_lot_count': solo_lot_count,
                                'median_num_terms': median_num_terms
                            }, index=[key])
        out_df = pd.concat([new_row, out_df.loc[:]]).reset_index(drop=True)
    
    out_df['solo_lot_pct'] = out_df.loc[out_df['solo_lot_count'] > 0].solo_lot_count / out_df.loc[out_df['solo_lot_count'] > 0].term_lot_count
    out_df['all_term_lot_count'] = covenanted_lots_df.shape[0]
    out_df['pct_of_cov_lots'] = out_df['term_lot_count'] / out_df['all_term_lot_count']
    
    out_df = out_df.sort_values(['pct_of_cov_lots'], ascending=False)
    out_df.fillna(0, inplace=True)
    out_df['workflow'] = workflow_name
    return out_df[['workflow', 'term', 'term_lot_count', 'all_term_lot_count', 'solo_lot_count', 'solo_lot_pct', 'median_num_terms', 'pct_of_cov_lots']]

# %%
dakota_term_stats_by_lot = calculate_term_stats_by_lot('MN Dakota County')
dakota_term_stats_by_lot
# Out:
# /var/folders/3v/0mvr8p6126n1yv0zq8vn8zyr0000gn/T/ipykernel_54604/3815395501.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   out_df = pd.concat([new_row, out_df.loc[:]]).reset_index(drop=True)
#             workflow               term term_lot_count  all_term_lot_count  \
# 15  MN Dakota County          caucasian            456                 720
# 5   MN Dakota County  domestic servants            318                 720
# 27  MN Dakota County        nationality            217                 720
# 2   MN Dakota County              negro            158                 720
# 1   MN Dakota County            chinese            120                 720
# 6   MN Dakota County           japanese            118                 720
# 25  MN Dakota County          mongolian            117                 720
# 21  MN Dakota County            african             76                 720
# 10  MN Dakota County            turkish             69                 720
# 22  MN Dakota County            moorish             67                 720
# 14  MN Dakota County    occupied by any             60                 720
# 4   MN Dakota County            colored             59                 720
# 17  MN Dakota County         white race             38                 720
# 24  MN Dakota County     persons not of              4                 720
# 7   MN Dakota County             racial              1                 720
# 11  MN Dakota County              malay              0                 720
# 20  MN Dakota County            mexican              0                 720
# 26  MN Dakota County            italian              0                 720
# 3   MN Dakota County             polish              0                 720
# 23  MN Dakota County            persian              0                 720
# 19  MN Dakota County             mulato              0                 720
# 12  MN Dakota County              irish              0                 720
# 18  MN Dakota County            citizen              0                 720
# 16  MN Dakota County             hebrew              0                 720
# 8   MN Dakota County             syrian              0                 720
# 9   MN Dakota County              aryan              0                 720
# 13  MN Dakota County               jew               0                 720
# 0   MN Dakota County             jewish              0                 720
#
#    solo_lot_count  solo_lot_pct  median_num_terms pct_of_cov_lots
# 15            120      0.263158               2.0        0.633333
# 5               0      0.000000               3.0        0.441667
# 27              0      0.000000               3.0        0.301389
# 2              35      0.221519               3.0        0.219444
# 1               0      0.000000               7.0        0.166667
# 6               0      0.000000               7.0        0.163889
# 25              0      0.000000               7.0          0.1625
# 21              7      0.092105               7.0        0.105556
# 10              0      0.000000               7.0        0.095833
# 22              0      0.000000               7.0        0.093056
# 14              0      0.000000               2.0        0.083333
# 4              11      0.186441               2.0        0.081944
# 17              0      0.000000               2.0        0.052778
# 24              0      0.000000               2.0        0.005556
# 7               1      1.000000               1.0        0.001389
# 11              0      0.000000               0.0             0.0
# 20              0      0.000000               0.0             0.0
# 26              0      0.000000               0.0             0.0
# 3               0      0.000000               0.0             0.0
# 23              0      0.000000               0.0             0.0
# 19              0      0.000000               0.0             0.0
# 12              0      0.000000               0.0             0.0
# 18              0      0.000000               0.0             0.0
# 16              0      0.000000               0.0             0.0
# 8               0      0.000000               0.0             0.0
# 9               0      0.000000               0.0             0.0
# 13              0      0.000000               0.0             0.0
# 0               0      0.000000               0.0             0.0

# %%
milw_term_stats_by_lot = calculate_term_stats_by_lot('WI Milwaukee County')
milw_term_stats_by_lot
# Out:
# /var/folders/3v/0mvr8p6126n1yv0zq8vn8zyr0000gn/T/ipykernel_54604/3815395501.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   out_df = pd.concat([new_row, out_df.loc[:]]).reset_index(drop=True)
#                workflow               term term_lot_count  all_term_lot_count  \
# 21  WI Milwaukee County         white race           8497               20030
# 9   WI Milwaukee County  domestic servants           7472               20030
# 18  WI Milwaukee County    occupied by any           6358               20030
# 8   WI Milwaukee County            colored           5959               20030
# 19  WI Milwaukee County          caucasian           4025               20030
# 6   WI Milwaukee County              negro           1373               20030
# 1   WI Milwaukee County          ethiopian           1200               20030
# 4   WI Milwaukee County      person not of            601               20030
# 32  WI Milwaukee County          mongolian            363               20030
# 22  WI Milwaukee County            citizen            240               20030
# 34  WI Milwaukee County        nationality            209               20030
# 26  WI Milwaukee County            african            171               20030
# 5   WI Milwaukee County          not white              7               20030
# 30  WI Milwaukee County            moorish              0               20030
# 28  WI Milwaukee County           armenian              0               20030
# 27  WI Milwaukee County            mulatto              0               20030
# 25  WI Milwaukee County            mexican              0               20030
# 24  WI Milwaukee County            simitic              0               20030
# 31  WI Milwaukee County     persons not of              0               20030
# 33  WI Milwaukee County            italian              0               20030
# 23  WI Milwaukee County             mulato              0               20030
# 29  WI Milwaukee County            persian              0               20030
# 0   WI Milwaukee County             jewish              0               20030
# 20  WI Milwaukee County             hebrew              0               20030
# 16  WI Milwaukee County              irish              0               20030
# 15  WI Milwaukee County              malay              0               20030
# 14  WI Milwaukee County            turkish              0               20030
# 13  WI Milwaukee County              aryan              0               20030
# 12  WI Milwaukee County             syrian              0               20030
# 11  WI Milwaukee County             racial              0               20030
# 10  WI Milwaukee County           japanese              0               20030
# 7   WI Milwaukee County             polish              0               20030
# 3   WI Milwaukee County            chinese              0               20030
# 2   WI Milwaukee County            semetic              0               20030
# 17  WI Milwaukee County               jew               0               20030
#
#    solo_lot_count  solo_lot_pct  median_num_terms pct_of_cov_lots
# 21           1133      0.133341               2.0        0.424214
# 9             286      0.038276               2.0         0.37304
# 18              0      0.000000               3.0        0.317424
# 8            5229      0.877496               1.0        0.297504
# 19            632      0.157019               2.0        0.200949
# 6               2      0.001457               2.0        0.068547
# 1               0      0.000000               2.0         0.05991
# 4               0      0.000000               2.0        0.030005
# 32              0      0.000000               2.0        0.018123
# 22              0      0.000000               3.0        0.011982
# 34              0      0.000000               3.0        0.010434
# 26            161      0.941520               1.0        0.008537
# 5               0      0.000000               2.0        0.000349
# 30              0      0.000000               0.0             0.0
# 28              0      0.000000               0.0             0.0
# 27              0      0.000000               0.0             0.0
# 25              0      0.000000               0.0             0.0
# 24              0      0.000000               0.0             0.0
# 31              0      0.000000               0.0             0.0
# 33              0      0.000000               0.0             0.0
# 23              0      0.000000               0.0             0.0
# 29              0      0.000000               0.0             0.0
# 0               0      0.000000               0.0             0.0
# 20              0      0.000000               0.0             0.0
# 16              0      0.000000               0.0             0.0
# 15              0      0.000000               0.0             0.0
# 14              0      0.000000               0.0             0.0
# 13              0      0.000000               0.0             0.0
# 12              0      0.000000               0.0             0.0
# 11              0      0.000000               0.0             0.0
# 10              0      0.000000               0.0             0.0
# 7               0      0.000000               0.0             0.0
# 3               0      0.000000               0.0             0.0
# 2               0      0.000000               0.0             0.0
# 17              0      0.000000               0.0             0.0

# %%
milw_term_stats_by_doc = calculate_term_stats_by_doc('WI Milwaukee County')
milw_term_stats_by_doc
# Out:
#    matched_terms__term  DeedPages  Retired subjects  Confirmed covenants  \
# 1              citizen       6263            3430.0                 20.0
# 2              colored       6117            3382.0               3180.0
# 3           white race       2652            1601.0               1596.0
# 0      occupied by any       7289            1064.0               1060.0
# 4               polish       1683             635.0                  1.0
# 5            caucasian        999             618.0                612.0
# 6    domestic servants        830             478.0                475.0
# 7               jewish        714             425.0                  2.0
# 8              african        655             268.0                192.0
# 9              italian        378             206.0                  3.0
# 10         nationality        327             178.0                 18.0
# 13               negro        161              91.0                 39.0
# 12               irish        179              72.0                  0.0
# 14              hebrew        109              59.0                  2.0
# 15             persian         85              56.0                  0.0
# 16             chinese         84              47.0                  2.0
# 18       person not of         71              43.0                 42.0
# 11                jew         289              32.0                  0.0
# 21            japanese         53              31.0                  2.0
# 22           ethiopian         46              28.0                 28.0
# 17             mexican         71              24.0                  0.0
# 19               malay         54              24.0                  0.0
# 23              racial         37              17.0                  0.0
# 24            armenian         32              17.0                  0.0
# 25             turkish         30              15.0                  0.0
# 26           mongolian         19              12.0                 12.0
# 28           not white         12              10.0                  9.0
# 20               aryan         53               9.0                  0.0
# 27              syrian         18               8.0                  0.0
# 29              mulato         10               3.0                  1.0
# 30             mulatto          7               3.0                  2.0
# 31      persons not of          3               1.0                  0.0
# 32             moorish          1               1.0                  0.0
# 33             semetic          1               0.0                  0.0
# 34             simitic          1               0.0                  0.0
# 35                   0          0               0.0                  0.0
#
#     Confirm rate  Pct of covenants
# 1       0.005831          0.003436
# 2       0.940272          0.546392
# 3       0.996877          0.274227
# 0       0.996241          0.182131
# 4       0.001575          0.000172
# 5       0.990291          0.105155
# 6       0.993724          0.081615
# 7       0.004706          0.000344
# 8       0.716418          0.032990
# 9       0.014563          0.000515
# 10      0.101124          0.003093
# 13      0.428571          0.006701
# 12      0.000000          0.000000
# 14      0.033898          0.000344
# 15      0.000000          0.000000
# 16      0.042553          0.000344
# 18      0.976744          0.007216
# 11      0.000000          0.000000
# 21      0.064516          0.000344
# 22      1.000000          0.004811
# 17      0.000000          0.000000
# 19      0.000000          0.000000
# 23      0.000000          0.000000
# 24      0.000000          0.000000
# 25      0.000000          0.000000
# 26      1.000000          0.002062
# 28      0.900000          0.001546
# 20      0.000000          0.000000
# 27      0.000000          0.000000
# 29      0.333333          0.000172
# 30      0.666667          0.000344
# 31      0.000000          0.000000
# 32      0.000000          0.000000
# 33           NaN          0.000000
# 34           NaN          0.000000
# 35           NaN          0.000000

# %%
anoka_term_stats_by_doc = calculate_term_stats_by_doc('MN Anoka County')
anoka_term_stats_by_doc
# Out:
#    matched_terms__term  DeedPages  Retired subjects  Confirmed covenants  \
# 1            caucasian       1142             406.0                353.0
# 2               indian        990             298.0                  3.0
# 3              colored        577             195.0                155.0
# 4                negro        552             190.0                176.0
# 5                alien        492             121.0                  0.0
# 8               polish        131              55.0                  0.0
# 7               racial        133              49.0                 29.0
# 0              citizen       3904              48.0                  0.0
# 9        person not of         86              28.0                 28.0
# 10             persian         85              28.0                  0.0
# 6      occupied by any        152              26.0                 26.0
# 13         nationality         62              22.0                  0.0
# 16   domestic servants         34              15.0                 15.0
# 11               irish         72              13.0                  0.0
# 15             chinese         45              12.0                  0.0
# 12             african         65              11.0                  0.0
# 17               hindu         29               8.0                  0.0
# 18               malay         22               6.0                  0.0
# 22              jewish         14               6.0                  0.0
# 19             italian         22               5.0                  0.0
# 20              syrian         16               5.0                  0.0
# 14                jew          56               4.0                  0.0
# 24             mexican          9               4.0                  0.0
# 26          white race          4               2.0                  2.0
# 28              mulato          3               2.0                  0.0
# 23              hebrew          9               1.0                  0.0
# 27      persons not of          4               1.0                  1.0
# 29             turkish          1               1.0                  0.0
# 30           not white          1               1.0                  0.0
# 21            japanese         14               0.0                  0.0
# 25               aryan          5               0.0                  0.0
# 31                   0          0               0.0                  0.0
#
#     Confirm rate  Pct of covenants
# 1       0.869458          0.605489
# 2       0.010067          0.005146
# 3       0.794872          0.265866
# 4       0.926316          0.301887
# 5       0.000000          0.000000
# 8       0.000000          0.000000
# 7       0.591837          0.049743
# 0       0.000000          0.000000
# 9       1.000000          0.048027
# 10      0.000000          0.000000
# 6       1.000000          0.044597
# 13      0.000000          0.000000
# 16      1.000000          0.025729
# 11      0.000000          0.000000
# 15      0.000000          0.000000
# 12      0.000000          0.000000
# 17      0.000000          0.000000
# 18      0.000000          0.000000
# 22      0.000000          0.000000
# 19      0.000000          0.000000
# 20      0.000000          0.000000
# 14      0.000000          0.000000
# 24      0.000000          0.000000
# 26      1.000000          0.003431
# 28      0.000000          0.000000
# 23      0.000000          0.000000
# 27      1.000000          0.001715
# 29      0.000000          0.000000
# 30      0.000000          0.000000
# 21           NaN          0.000000
# 25           NaN          0.000000
# 31           NaN          0.000000

# %%
anoka_term_stats_by_lot = calculate_term_stats_by_lot('MN Anoka County')
anoka_term_stats_by_lot
# Out:
# /var/folders/3v/0mvr8p6126n1yv0zq8vn8zyr0000gn/T/ipykernel_54604/3815395501.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   out_df = pd.concat([new_row, out_df.loc[:]]).reset_index(drop=True)
#            workflow               term term_lot_count  all_term_lot_count  \
# 17  MN Anoka County          caucasian            633                 780
# 1   MN Anoka County      person not of            126                 780
# 7   MN Anoka County  domestic servants            124                 780
# 16  MN Anoka County    occupied by any            115                 780
# 4   MN Anoka County              negro            112                 780
# 6   MN Anoka County            colored            108                 780
# 9   MN Anoka County             racial             27                 780
# 19  MN Anoka County         white race              6                 780
# 24  MN Anoka County            african              2                 780
# 0   MN Anoka County            chinese              2                 780
# 8   MN Anoka County           japanese              2                 780
# 26  MN Anoka County     persons not of              1                 780
# 20  MN Anoka County             indian              0                 780
# 25  MN Anoka County            persian              0                 780
# 23  MN Anoka County            mexican              0                 780
# 22  MN Anoka County             mulato              0                 780
# 27  MN Anoka County            italian              0                 780
# 28  MN Anoka County              alien              0                 780
# 29  MN Anoka County        nationality              0                 780
# 21  MN Anoka County            citizen              0                 780
# 15  MN Anoka County               jew               0                 780
# 18  MN Anoka County             hebrew              0                 780
# 14  MN Anoka County              irish              0                 780
# 13  MN Anoka County              malay              0                 780
# 12  MN Anoka County            turkish              0                 780
# 11  MN Anoka County              aryan              0                 780
# 10  MN Anoka County             syrian              0                 780
# 5   MN Anoka County             polish              0                 780
# 3   MN Anoka County          not white              0                 780
# 2   MN Anoka County              hindu              0                 780
# 30  MN Anoka County             jewish              0                 780
#
#    solo_lot_count  solo_lot_pct  median_num_terms pct_of_cov_lots
# 17            313      0.494471               2.0        0.811538
# 1               0      0.000000               2.0        0.161538
# 7               0      0.000000               2.0        0.158974
# 16              0      0.000000               2.0        0.147436
# 4               4      0.035714               2.0         0.14359
# 6               2      0.018519               2.0        0.138462
# 9              27      1.000000               1.0        0.034615
# 19              6      1.000000               1.0        0.007692
# 24              0      0.000000               4.0        0.002564
# 0               0      0.000000               4.0        0.002564
# 8               0      0.000000               4.0        0.002564
# 26              0      0.000000               2.0        0.001282
# 20              0      0.000000               0.0             0.0
# 25              0      0.000000               0.0             0.0
# 23              0      0.000000               0.0             0.0
# 22              0      0.000000               0.0             0.0
# 27              0      0.000000               0.0             0.0
# 28              0      0.000000               0.0             0.0
# 29              0      0.000000               0.0             0.0
# 21              0      0.000000               0.0             0.0
# 15              0      0.000000               0.0             0.0
# 18              0      0.000000               0.0             0.0
# 14              0      0.000000               0.0             0.0
# 13              0      0.000000               0.0             0.0
# 12              0      0.000000               0.0             0.0
# 11              0      0.000000               0.0             0.0
# 10              0      0.000000               0.0             0.0
# 5               0      0.000000               0.0             0.0
# 3               0      0.000000               0.0             0.0
# 2               0      0.000000               0.0             0.0
# 30              0      0.000000               0.0             0.0

# %%
all_terms = list(MatchTerm.objects.exclude(term=None).distinct().values_list('term', flat=True))
sorted(all_terms)
# Out:
# [' alien',
#  ' aryan',
#  ' indian',
#  ' indian ',
#  ' jew ',
#  ' malay',
#  ' not white',
#  ' polish',
#  'african',
#  'armenian',
#  'blood group',
#  'caucasian',
#  'caucasion',
#  'caucausian',
#  'certificate of death',
#  'chinese',
#  'citizen',
#  'colored',
#  'date of death',
#  'death certificate',
#  'domestic servants',
#  'ethiopian',
#  'hebrew',
#  'hindu',
#  'irish',
#  'italian',
#  'japanese',
#  'jewish',
#  'mexican',
#  'mongolian',
#  'moorish',
#  'mulato',
#  'mulatto',
#  'nationality',
#  'negro',
#  'occupied by any',
#  'persian',
#  'person not of',
#  'persons not of',
#  'racial',
#  'report of transfer',
#  'semetic',
#  'semitic',
#  'simitic',
#  'syrian',
#  'transfer or discharge',
#  'turkish',
#  'white race']

# %%
hennepin_cov_df = pd.read_csv('https://github.com/UMNLibraries/mp-us-racial-covenants/raw/main/mn-hennepin-county/covenants-mn-hennepin-county.csv')
hennepin_cov_df.head()
# Out:
# /var/folders/3v/0mvr8p6126n1yv0zq8vn8zyr0000gn/T/ipykernel_54604/3968416624.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   hennepin_cov_df = pd.read_csv('https://github.com/UMNLibraries/mp-us-racial-covenants/raw/main/mn-hennepin-county/covenants-mn-hennepin-county.csv')
#    db_id               workflow cnty_name  cnty_fips    doc_num  deed_year  \
# 0      0  Zooniverse -- Torrens  Hennepin      27053  T00155264       1940
# 1      1  Zooniverse -- Torrens  Hennepin      27053  T00220683       1946
# 2      2  Zooniverse -- Torrens  Hennepin      27053  T00220683       1946
# 3      3  Zooniverse -- Torrens  Hennepin      27053  T00219828       1946
# 4      4  Zooniverse -- Torrens  Hennepin      27053  T00220683       1946
#
#   deed_date   exec_date                                           cov_text  \
# 0       NaN  1940-03-23  Subject to certain racial and building restric...
# 1       NaN  1946-04-02  no persons of any race other than of the Cauca...
# 2       NaN  1946-04-02  no persons of any race other than of the Cauca...
# 3       NaN  1946-03-01                      racial restrictions of record
# 4       NaN  1946-04-02  no persons of any race other than of the Cauca...
#
#                                   seller  ... geocd_dist    cov_type  \
# 0  James E. O'Brien and Agnes B. O'Brien  ...   4.563108  zooniverse
# 1             Rudolph C. & Opal M. Soens  ...   0.000000  zooniverse
# 2             Rudolph C. & Opal M. Soens  ...   0.200013  zooniverse
# 3                    A. G. Bogen Company  ...   0.000000  zooniverse
# 4             Rudolph C. & Opal M. Soens  ...   0.000000  zooniverse
#
#   match_type manual_cx  dt_updated zn_subj_id zn_dt_ret image_ids  med_score  \
# 0        NaN       NaN         NaN        NaN       NaN       NaN        NaN
# 1        NaN       NaN         NaN        NaN       NaN       NaN        NaN
# 2        NaN       NaN         NaN        NaN       NaN       NaN        NaN
# 3        NaN       NaN         NaN        NaN       NaN       NaN        NaN
# 4        NaN       NaN         NaN        NaN       NaN       NaN        NaN
#
#    plat_dbid
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 35 columns]

# %%
hennepin_term_stats_by_lot = calculate_term_stats_by_lot('MN Hennepin County', all_terms, hennepin_cov_df)
hennepin_term_stats_by_lot
# Out:
# /var/folders/3v/0mvr8p6126n1yv0zq8vn8zyr0000gn/T/ipykernel_54604/3815395501.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   out_df = pd.concat([new_row, out_df.loc[:]]).reset_index(drop=True)
#               workflow                   term term_lot_count  \
# 18  MN Hennepin County              caucasian          16461
# 6   MN Hennepin County                colored           3766
# 17  MN Hennepin County        occupied by any           3519
# 7   MN Hennepin County      domestic servants           2739
# 4   MN Hennepin County                  negro           2007
# 32  MN Hennepin County                african           1925
# 46  MN Hennepin County                chinese           1486
# 38  MN Hennepin County              mongolian           1445
# 35  MN Hennepin County                moorish           1416
# 8   MN Hennepin County               japanese           1371
# 13  MN Hennepin County                turkish           1301
# 9   MN Hennepin County                 racial            927
# 20  MN Hennepin County             white race            452
# 47  MN Hennepin County          person not of            397
# 42  MN Hennepin County            nationality            276
# 19  MN Hennepin County                 hebrew             37
# 30  MN Hennepin County                semitic             32
# 12  MN Hennepin County                  aryan              3
# 45  MN Hennepin County                semetic              1
# 34  MN Hennepin County               armenian              0
# 36  MN Hennepin County                persian              0
# 33  MN Hennepin County                mulatto              0
# 41  MN Hennepin County                  alien              0
# 37  MN Hennepin County         persons not of              0
# 39  MN Hennepin County                indian               0
# 40  MN Hennepin County                italian              0
# 43  MN Hennepin County                 jewish              0
# 44  MN Hennepin County              ethiopian              0
# 31  MN Hennepin County              caucasion              0
# 0   MN Hennepin County             caucausian              0
# 29  MN Hennepin County   certificate of death              0
# 28  MN Hennepin County                mexican              0
# 2   MN Hennepin County                  hindu              0
# 3   MN Hennepin County              not white              0
# 5   MN Hennepin County                 polish              0
# 10  MN Hennepin County                 syrian              0
# 11  MN Hennepin County            blood group              0
# 14  MN Hennepin County                  malay              0
# 15  MN Hennepin County                  irish              0
# 16  MN Hennepin County                   jew               0
# 21  MN Hennepin County                 indian              0
# 22  MN Hennepin County      death certificate              0
# 23  MN Hennepin County                citizen              0
# 1   MN Hennepin County  transfer or discharge              0
# 25  MN Hennepin County     report of transfer              0
# 26  MN Hennepin County          date of death              0
# 27  MN Hennepin County                simitic              0
# 24  MN Hennepin County                 mulato              0
#
#     all_term_lot_count solo_lot_count  solo_lot_pct  median_num_terms  \
# 18               24118          10510      0.638479               1.0
# 6                24118           3403      0.903611               1.0
# 17               24118             36      0.010230               2.0
# 7                24118              0      0.000000               2.0
# 4                24118            330      0.164425               7.0
# 32               24118            399      0.207273               7.0
# 46               24118              0      0.000000               7.0
# 38               24118              0      0.000000               7.0
# 35               24118              0      0.000000               7.0
# 8                24118              0      0.000000               7.0
# 13               24118              0      0.000000               7.0
# 9                24118            926      0.998921               1.0
# 20               24118            408      0.902655               1.0
# 47               24118              0      0.000000               2.0
# 42               24118              0      0.000000               3.0
# 19               24118              0      0.000000               3.0
# 30               24118              0      0.000000               8.0
# 12               24118              0      0.000000               2.0
# 45               24118              0      0.000000               8.0
# 34               24118              0      0.000000               0.0
# 36               24118              0      0.000000               0.0
# 33               24118              0      0.000000               0.0
# 41               24118              0      0.000000               0.0
# 37               24118              0      0.000000               0.0
# 39               24118              0      0.000000               0.0
# 40               24118              0      0.000000               0.0
# 43               24118              0      0.000000               0.0
# 44               24118              0      0.000000               0.0
# 31               24118              0      0.000000               0.0
# 0                24118              0      0.000000               0.0
# 29               24118              0      0.000000               0.0
# 28               24118              0      0.000000               0.0
# 2                24118              0      0.000000               0.0
# 3                24118              0      0.000000               0.0
# 5                24118              0      0.000000               0.0
# 10               24118              0      0.000000               0.0
# 11               24118              0      0.000000               0.0
# 14               24118              0      0.000000               0.0
# 15               24118              0      0.000000               0.0
# 16               24118              0      0.000000               0.0
# 21               24118              0      0.000000               0.0
# 22               24118              0      0.000000               0.0
# 23               24118              0      0.000000               0.0
# 1                24118              0      0.000000               0.0
# 25               24118              0      0.000000               0.0
# 26               24118              0      0.000000               0.0
# 27               24118              0      0.000000               0.0
# 24               24118              0      0.000000               0.0
#
#    pct_of_cov_lots
# 18        0.682519
# 6         0.156149
# 17        0.145908
# 7         0.113567
# 4         0.083216
# 32        0.079816
# 46        0.061614
# 38        0.059914
# 35        0.058711
# 8         0.056846
# 13        0.053943
# 9         0.038436
# 20        0.018741
# 47        0.016461
# 42        0.011444
# 19        0.001534
# 30        0.001327
# 12        0.000124
# 45        0.000041
# 34             0.0
# 36             0.0
# 33             0.0
# 41             0.0
# 37             0.0
# 39             0.0
# 40             0.0
# 43             0.0
# 44             0.0
# 31             0.0
# 0              0.0
# 29             0.0
# 28             0.0
# 2              0.0
# 3              0.0
# 5              0.0
# 10             0.0
# 11             0.0
# 14             0.0
# 15             0.0
# 16             0.0
# 21             0.0
# 22             0.0
# 23             0.0
# 1              0.0
# 25             0.0
# 26             0.0
# 27             0.0
# 24             0.0

# %%
ramsey_term_stats_by_lot = calculate_term_stats_by_lot('Ramsey County', all_terms)
ramsey_term_stats_by_lot
# Out:
# /var/folders/3v/0mvr8p6126n1yv0zq8vn8zyr0000gn/T/ipykernel_54604/3815395501.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   out_df = pd.concat([new_row, out_df.loc[:]]).reset_index(drop=True)
#          workflow                   term term_lot_count  all_term_lot_count  \
# 18  Ramsey County              caucasian           2282                5458
# 6   Ramsey County                colored           1749                5458
# 17  Ramsey County        occupied by any           1052                5458
# 4   Ramsey County                  negro            774                5458
# 32  Ramsey County                african            631                5458
# 46  Ramsey County                chinese            571                5458
# 8   Ramsey County               japanese            570                5458
# 7   Ramsey County      domestic servants            558                5458
# 38  Ramsey County              mongolian            458                5458
# 13  Ramsey County                turkish            399                5458
# 35  Ramsey County                moorish            388                5458
# 31  Ramsey County              caucasion            207                5458
# 20  Ramsey County             white race            132                5458
# 45  Ramsey County                semetic            128                5458
# 19  Ramsey County                 hebrew             47                5458
# 2   Ramsey County                  hindu             25                5458
# 9   Ramsey County                 racial             23                5458
# 30  Ramsey County                semitic             13                5458
# 47  Ramsey County          person not of              5                5458
# 0   Ramsey County             caucausian              4                5458
# 43  Ramsey County                 jewish              2                5458
# 16  Ramsey County                   jew               0                5458
# 21  Ramsey County                 indian              0                5458
# 3   Ramsey County              not white              0                5458
# 5   Ramsey County                 polish              0                5458
# 44  Ramsey County              ethiopian              0                5458
# 42  Ramsey County            nationality              0                5458
# 41  Ramsey County                  alien              0                5458
# 40  Ramsey County                italian              0                5458
# 39  Ramsey County                indian               0                5458
# 10  Ramsey County                 syrian              0                5458
# 37  Ramsey County         persons not of              0                5458
# 36  Ramsey County                persian              0                5458
# 11  Ramsey County            blood group              0                5458
# 34  Ramsey County               armenian              0                5458
# 33  Ramsey County                mulatto              0                5458
# 12  Ramsey County                  aryan              0                5458
# 14  Ramsey County                  malay              0                5458
# 15  Ramsey County                  irish              0                5458
# 29  Ramsey County   certificate of death              0                5458
# 28  Ramsey County                mexican              0                5458
# 27  Ramsey County                simitic              0                5458
# 26  Ramsey County          date of death              0                5458
# 25  Ramsey County     report of transfer              0                5458
# 1   Ramsey County  transfer or discharge              0                5458
# 23  Ramsey County                citizen              0                5458
# 22  Ramsey County      death certificate              0                5458
# 24  Ramsey County                 mulato              0                5458
#
#    solo_lot_count  solo_lot_pct  median_num_terms pct_of_cov_lots
# 18           1035      0.453550               2.0        0.418102
# 6            1564      0.894225               1.0        0.320447
# 17              4      0.003802               2.0        0.192745
# 4              55      0.071059               6.0         0.14181
# 32            199      0.315372               7.0         0.11561
# 46              0      0.000000               7.0        0.104617
# 8               0      0.000000               7.0        0.104434
# 7               0      0.000000               2.0        0.102235
# 38              0      0.000000               7.0        0.083914
# 13              0      0.000000               7.0        0.073104
# 35              0      0.000000               7.0        0.071088
# 31            206      0.995169               1.0        0.037926
# 20            131      0.992424               1.0        0.024185
# 45             79      0.617188               1.0        0.023452
# 19              0      0.000000               5.0        0.008611
# 2               0      0.000000               4.0         0.00458
# 9              23      1.000000               1.0        0.004214
# 30              1      0.076923               3.0        0.002382
# 47              0      0.000000               3.0        0.000916
# 0               0      0.000000               2.0        0.000733
# 43              0      0.000000               2.0        0.000366
# 16              0      0.000000               0.0             0.0
# 21              0      0.000000               0.0             0.0
# 3               0      0.000000               0.0             0.0
# 5               0      0.000000               0.0             0.0
# 44              0      0.000000               0.0             0.0
# 42              0      0.000000               0.0             0.0
# 41              0      0.000000               0.0             0.0
# 40              0      0.000000               0.0             0.0
# 39              0      0.000000               0.0             0.0
# 10              0      0.000000               0.0             0.0
# 37              0      0.000000               0.0             0.0
# 36              0      0.000000               0.0             0.0
# 11              0      0.000000               0.0             0.0
# 34              0      0.000000               0.0             0.0
# 33              0      0.000000               0.0             0.0
# 12              0      0.000000               0.0             0.0
# 14              0      0.000000               0.0             0.0
# 15              0      0.000000               0.0             0.0
# 29              0      0.000000               0.0             0.0
# 28              0      0.000000               0.0             0.0
# 27              0      0.000000               0.0             0.0
# 26              0      0.000000               0.0             0.0
# 25              0      0.000000               0.0             0.0
# 1               0      0.000000               0.0             0.0
# 23              0      0.000000               0.0             0.0
# 22              0      0.000000               0.0             0.0
# 24              0      0.000000               0.0             0.0

# %%
combined_stats_by_lot = pd.concat([hennepin_term_stats_by_lot, ramsey_term_stats_by_lot, dakota_term_stats_by_lot, milw_term_stats_by_lot, anoka_term_stats_by_lot], axis=0)

# %%
alt.Chart(
    combined_stats_by_lot[combined_stats_by_lot['term_lot_count'] > 0].sort_values('pct_of_cov_lots', ascending=False),
    title="Percent of covenanted lots with each term, by County"
).mark_bar().encode(
   x=alt.X('term', axis=alt.Axis(labelAngle=0)).sort("-y"),
   xOffset='workflow',
   y=alt.Y('pct_of_cov_lots', axis=alt.Axis(grid=False)),
   color='workflow'
).configure_view(
    stroke=None,
)
# Out:
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
def build_term_freq_chart(df):
    return alt.Chart(df[df['term_lot_count'] > 0].sort_values('pct_of_cov_lots', ascending=False), title=df.iloc[0].workflow).mark_bar().encode(
        x=alt.X('term').sort("-y"),
        y='pct_of_cov_lots'
    )

# %%
combined_stats_by_lot = pd.concat([
    hennepin_term_stats_by_lot,
    ramsey_term_stats_by_lot,
    dakota_term_stats_by_lot,
    milw_term_stats_by_lot, 
    anoka_term_stats_by_lot
])
combined_stats_by_lot
# Out:
#               workflow               term term_lot_count  all_term_lot_count  \
# 18  MN Hennepin County          caucasian          16461               24118
# 6   MN Hennepin County            colored           3766               24118
# 17  MN Hennepin County    occupied by any           3519               24118
# 7   MN Hennepin County  domestic servants           2739               24118
# 4   MN Hennepin County              negro           2007               24118
# ..                 ...                ...            ...                 ...
# 10     MN Anoka County             syrian              0                 780
# 5      MN Anoka County             polish              0                 780
# 3      MN Anoka County          not white              0                 780
# 2      MN Anoka County              hindu              0                 780
# 30     MN Anoka County             jewish              0                 780
#
#    solo_lot_count  solo_lot_pct  median_num_terms pct_of_cov_lots
# 18          10510      0.638479               1.0        0.682519
# 6            3403      0.903611               1.0        0.156149
# 17             36      0.010230               2.0        0.145908
# 7               0      0.000000               2.0        0.113567
# 4             330      0.164425               7.0        0.083216
# ..            ...           ...               ...             ...
# 10              0      0.000000               0.0             0.0
# 5               0      0.000000               0.0             0.0
# 3               0      0.000000               0.0             0.0
# 2               0      0.000000               0.0             0.0
# 30              0      0.000000               0.0             0.0
#
# [190 rows x 8 columns]

# %%
grouped_stats_by_lot = combined_stats_by_lot[[
    'term',
    'term_lot_count',
    'all_term_lot_count',
    'solo_lot_count'
]].groupby(['term']).agg('sum').sort_values('term_lot_count', ascending=False).reset_index()
grouped_stats_by_lot['all_term_lot_count'] = grouped_stats_by_lot['all_term_lot_count'].max()
grouped_stats_by_lot = grouped_stats_by_lot[grouped_stats_by_lot['term_lot_count'] > 0]
grouped_stats_by_lot['pct_of_cov_lots'] = grouped_stats_by_lot['term_lot_count'] / grouped_stats_by_lot['all_term_lot_count']
grouped_stats_by_lot['solo_lot_pct'] = grouped_stats_by_lot['solo_lot_count'] / grouped_stats_by_lot['term_lot_count']
grouped_stats_by_lot
# Out:
#                  term term_lot_count  all_term_lot_count solo_lot_count  \
# 0           caucasian          23857               51106          12610
# 1             colored          11641               51106          10209
# 2   domestic servants          11211               51106            286
# 3     occupied by any          11104               51106             40
# 4          white race           9125               51106           1678
# 5               negro           4424               51106            426
# 6             african           2805               51106            766
# 7           mongolian           2383               51106              0
# 8             chinese           2179               51106              0
# 9            japanese           2061               51106              0
# 10            moorish           1871               51106              0
# 11            turkish           1769               51106              0
# 12          ethiopian           1200               51106              0
# 13      person not of           1129               51106              0
# 14             racial            978               51106            977
# 15        nationality            702               51106              0
# 16            citizen            240               51106              0
# 17          caucasion            207               51106            206
# 18            semetic            129               51106             79
# 19             hebrew             84               51106              0
# 20            semitic             45               51106              1
# 21              hindu             25               51106              0
# 22          not white              7               51106              0
# 23     persons not of              5               51106              0
# 24         caucausian              4               51106              0
# 25              aryan              3               51106              0
# 26             jewish              2               51106              0
#
#    pct_of_cov_lots solo_lot_pct
# 0         0.466814     0.528566
# 1         0.227781     0.876987
# 2         0.219368     0.025511
# 3         0.217274     0.003602
# 4          0.17855      0.18389
# 5         0.086565     0.096293
# 6         0.054886     0.273084
# 7         0.046629          0.0
# 8         0.042637          0.0
# 9         0.040328          0.0
# 10         0.03661          0.0
# 11        0.034614          0.0
# 12        0.023481          0.0
# 13        0.022091          0.0
# 14        0.019137     0.998978
# 15        0.013736          0.0
# 16        0.004696          0.0
# 17         0.00405     0.995169
# 18        0.002524     0.612403
# 19        0.001644          0.0
# 20        0.000881     0.022222
# 21        0.000489          0.0
# 22        0.000137          0.0
# 23        0.000098          0.0
# 24        0.000078          0.0
# 25        0.000059          0.0
# 26        0.000039          0.0

# %%
grouped_stats_by_lot_display = grouped_stats_by_lot.copy().drop(columns=['all_term_lot_count', 'solo_lot_count'])
grouped_stats_by_lot_display = grouped_stats_by_lot_display.sort_values('pct_of_cov_lots', ascending=False)
grouped_stats_by_lot_display['Rank'] = grouped_stats_by_lot_display.index + 1
grouped_stats_by_lot_display['term_lot_count'] = grouped_stats_by_lot_display['term_lot_count'].apply(lambda x: f"{x:,}")
grouped_stats_by_lot_display['pct_of_cov_lots'] = grouped_stats_by_lot_display['pct_of_cov_lots'].apply(lambda x: f"{x:.1%}")
grouped_stats_by_lot_display['solo_lot_pct'] = grouped_stats_by_lot_display['solo_lot_pct'].apply(lambda x: f"{x:.1%}")
grouped_stats_by_lot_display = grouped_stats_by_lot_display[[
    'Rank', 'term', 'term_lot_count', 'pct_of_cov_lots', 'solo_lot_pct'
]]
grouped_stats_by_lot_display.rename(columns={
    'term': 'Term',
    'term_lot_count': 'Covenanted lot count',
    'pct_of_cov_lots': 'Percent of covenanted lots',
    'solo_lot_pct': 'Solo frequency',
}, inplace=True)

# out_dir = os.path.join(settings.BASE_DIR, '/nostat_exports')
grouped_stats_by_lot_display.to_csv('overall_frequency.csv', index=False)
grouped_stats_by_lot_display
# Out:
#     Rank               Term Covenanted lot count Percent of covenanted lots  \
# 0      1          caucasian               23,857                      46.7%
# 1      2            colored               11,641                      22.8%
# 2      3  domestic servants               11,211                      21.9%
# 3      4    occupied by any               11,104                      21.7%
# 4      5         white race                9,125                      17.9%
# 5      6              negro                4,424                       8.7%
# 6      7            african                2,805                       5.5%
# 7      8          mongolian                2,383                       4.7%
# 8      9            chinese                2,179                       4.3%
# 9     10           japanese                2,061                       4.0%
# 10    11            moorish                1,871                       3.7%
# 11    12            turkish                1,769                       3.5%
# 12    13          ethiopian                1,200                       2.3%
# 13    14      person not of                1,129                       2.2%
# 14    15             racial                  978                       1.9%
# 15    16        nationality                  702                       1.4%
# 16    17            citizen                  240                       0.5%
# 17    18          caucasion                  207                       0.4%
# 18    19            semetic                  129                       0.3%
# 19    20             hebrew                   84                       0.2%
# 20    21            semitic                   45                       0.1%
# 21    22              hindu                   25                       0.0%
# 22    23          not white                    7                       0.0%
# 23    24     persons not of                    5                       0.0%
# 24    25         caucausian                    4                       0.0%
# 25    26              aryan                    3                       0.0%
# 26    27             jewish                    2                       0.0%
#
#    Solo frequency
# 0           52.9%
# 1           87.7%
# 2            2.6%
# 3            0.4%
# 4           18.4%
# 5            9.6%
# 6           27.3%
# 7            0.0%
# 8            0.0%
# 9            0.0%
# 10           0.0%
# 11           0.0%
# 12           0.0%
# 13           0.0%
# 14          99.9%
# 15           0.0%
# 16           0.0%
# 17          99.5%
# 18          61.2%
# 19           0.0%
# 20           2.2%
# 21           0.0%
# 22           0.0%
# 23           0.0%
# 24           0.0%
# 25           0.0%
# 26           0.0%

# %%
for df in [hennepin_term_stats_by_lot, ramsey_term_stats_by_lot, dakota_term_stats_by_lot, milw_term_stats_by_lot, anoka_term_stats_by_lot]:
    chart = build_term_freq_chart(df)
    display(chart)
# Out:
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
def calculate_term_stats_by_year(workflow_name, terms_list_manual=False, cov_df_manual=False, exclude_terms=None):
    
    
    if isinstance(cov_df_manual, pd.DataFrame):
        workflow = None
        covenanted_lots_df = cov_df_manual[['db_id', 'cov_text', 'deed_year']].copy().fillna(0)
    else:
        workflow = ZooniverseWorkflow.objects.get(workflow_name=workflow_name)
        covenanted_lots_df = build_gdf(workflow)[['db_id', 'cov_text', 'deed_year']]
    
    if terms_list_manual:
        match_terms = terms_list_manual
    else:
        match_terms = [term for term in DeedPage.objects.filter(workflow=workflow).values_list('matched_terms__term', flat=True).distinct() if term is not None]

    if exclude_terms:
        match_terms = [term for term in match_terms if term not in exclude_terms]

    for term in match_terms:
        covenanted_lots_df[term] = covenanted_lots_df['cov_text'].str.contains(term, case=False)
    
    out_df = pd.DataFrame(columns=['term', 'year', 'term_lot_count'])
    for key, term in enumerate(match_terms):
        lot_counts = covenanted_lots_df[covenanted_lots_df[term] == True][
            ['db_id', 'deed_year']
        ].groupby(['deed_year']).agg('count').reset_index().rename(columns={
            'deed_year': 'year',
            'db_id': 'term_lot_count'
        })
        lot_counts['term'] = term
        lot_counts['workflow'] = workflow_name

        out_df = pd.concat([lot_counts, out_df.loc[:]]).reset_index(drop=True)
    out_df.fillna(0, inplace=True)
    return out_df[['workflow', 'term', 'year', 'term_lot_count']]

# %%
def build_term_freq_chart(df, num_terms=10):
    if num_terms:
        term_counts = df[['term', 'term_lot_count']].groupby(['term']).agg('sum').reset_index().sort_values('term_lot_count', ascending=False)
        df = df[df['term'].isin(term_counts['term'][0:num_terms])]

    return alt.Chart(df[df['term_lot_count'] > 0].sort_values('term_lot_count', ascending=False), title=df.iloc[0].workflow).mark_line().encode(
        x=alt.X('year:O'),
        y='term_lot_count',
        color='term'
    )

# %%
exclude_terms = ['occupied by any', 'domestic servants']

# %%
milw_term_stats_by_year = calculate_term_stats_by_year('WI Milwaukee County', False, False, exclude_terms)
build_term_freq_chart(milw_term_stats_by_year, 5)
# Out:
# /var/folders/3v/0mvr8p6126n1yv0zq8vn8zyr0000gn/T/ipykernel_54604/1316910966.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   out_df = pd.concat([lot_counts, out_df.loc[:]]).reset_index(drop=True)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
ramsey_term_stats_by_year = calculate_term_stats_by_year('Ramsey County', all_terms, False, exclude_terms)
build_term_freq_chart(ramsey_term_stats_by_year, 5)
# Out:
# /var/folders/3v/0mvr8p6126n1yv0zq8vn8zyr0000gn/T/ipykernel_54604/1316910966.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   out_df = pd.concat([lot_counts, out_df.loc[:]]).reset_index(drop=True)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
hennepin_term_stats_by_year = calculate_term_stats_by_year('MN Hennepin County', all_terms, hennepin_cov_df, exclude_terms)
hennepin_term_stats_by_year
build_term_freq_chart(hennepin_term_stats_by_year, 5)
# Out:
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
dakota_term_stats_by_year = calculate_term_stats_by_year('MN Dakota County', False, False, exclude_terms)
build_term_freq_chart(dakota_term_stats_by_year, 5)
# Out:
# /var/folders/3v/0mvr8p6126n1yv0zq8vn8zyr0000gn/T/ipykernel_54604/1316910966.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   out_df = pd.concat([lot_counts, out_df.loc[:]]).reset_index(drop=True)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
anoka_term_stats_by_year = calculate_term_stats_by_year('MN Anoka County', False, False, exclude_terms)
build_term_freq_chart(anoka_term_stats_by_year, 5)
# Out:
# /Users/mcorey/.local/share/virtualenvs/racial_covenants_processor-wniTpM7j/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %% [markdown]
# # Combined stats by doc (confirmation rate chart for NEH white paper)

# %%
combined_stats_by_doc = pd.concat([
    dakota_term_stats_by_doc,
    milw_term_stats_by_doc, 
    anoka_term_stats_by_doc
])
combined_stats_by_doc.rename(columns={'matched_terms__term': 'Term'}, inplace=True)
combined_stats_by_doc = combined_stats_by_doc[combined_stats_by_doc['Retired subjects'] > 0]
combined_stats_by_doc
# Out:
#               Term  DeedPages  Retired subjects  Confirmed covenants  \
# 1            negro        820             691.0                682.0
# 2      nationality        575             569.0                558.0
# 3         japanese        523             477.0                474.0
# 4          chinese        505             462.0                457.0
# 5        caucasian        466             451.0                444.0
# ..             ...        ...               ...                  ...
# 28          mulato          3               2.0                  0.0
# 23          hebrew          9               1.0                  0.0
# 27  persons not of          4               1.0                  1.0
# 29         turkish          1               1.0                  0.0
# 30       not white          1               1.0                  0.0
#
#     Confirm rate  Pct of covenants
# 1       0.986975          0.340489
# 2       0.980668          0.278582
# 3       0.993711          0.236645
# 4       0.989177          0.228158
# 5       0.984479          0.221667
# ..           ...               ...
# 28      0.000000          0.000000
# 23      0.000000          0.000000
# 27      1.000000          0.001715
# 29      0.000000          0.000000
# 30      0.000000          0.000000
#
# [90 rows x 6 columns]

# %%
grouped_stats_by_doc = combined_stats_by_doc[[
    'Term', 'Retired subjects', 'Confirmed covenants'
]].groupby('Term').agg('sum').reset_index()
grouped_stats_by_doc['Confirmation rate'] = grouped_stats_by_doc['Confirmed covenants'] / grouped_stats_by_doc['Retired subjects']
grouped_stats_by_doc = grouped_stats_by_doc.sort_values(['Confirmed covenants'], ascending=False)
grouped_stats_by_doc['Retired subjects'] = grouped_stats_by_doc['Retired subjects'].apply(lambda x: f"{int(x):,}")
grouped_stats_by_doc['Confirmed covenants'] = grouped_stats_by_doc['Confirmed covenants'].apply(lambda x: f"{int(x):,}")
grouped_stats_by_doc['Confirmation rate'] = grouped_stats_by_doc['Confirmation rate'].apply(lambda x: f"{x:.1%}")
grouped_stats_by_doc.reset_index(delete=True, inplace=True)
grouped_stats_by_doc['Rank'] = grouped_stats_by_doc.index + 1
grouped_stats_by_doc
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 9
#       7 grouped_stats_by_doc['Confirmed covenants'] = grouped_stats_by_doc['Confirmed covenants'].apply(lambda x: f"{int(x):,}")
#       8 grouped_stats_by_doc['Confirmation rate'] = grouped_stats_by_doc['Confirmation rate'].apply(lambda x: f"{x:.1%}")
# ----> 9 grouped_stats_by_doc.reset_index(delete=True, inplace=True)
#      10 grouped_stats_by_doc['Rank'] = grouped_stats_by_doc.index + 1
#      11 grouped_stats_by_doc
#
# TypeError: reset_index() got an unexpected keyword argument 'delete'

# %%
grouped_stats_by_doc.to_csv('frequency_by_doc.csv', index=False)
